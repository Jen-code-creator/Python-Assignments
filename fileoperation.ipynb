# %% [markdown]
# ### File Operation - Read and Write Files
#
# File handling is a crucial part of any Programming language. Python provides built-in functions and methods to read from and write to files, both text and binary. This lesson will cover basics of file handling, including reading and writing text files and binary files.

# %%
with open('example.txt','r') as file:
    content= file.read()
    print(content)
# Out:
# Hello I'm Jennifen Divya an Aspiring Data Scientist.
# Welcome to my channel.
# Learn with me in simple way

# %%
## Read a file line by line

with open('example.txt','r') as file:
    for line in file:
        print(line.strip()) ## .strip removes the new line character
# Out:
# Hello I'm Jennifen Divya an Aspiring Data Scientist.
# Welcome to my channel.
# Learn with me in simple way

# %%
## Writing a file(overwriting)

with open('example.txt','w') as file:
    file.write('Hello World!\n')
    file.write('I am a Data Scientist.')

# %%
## Writing a file(without overwriting)

with open('example.txt','a') as file:
    file.write("\nAppend operations taking place!")

# %%
## writing a list of lines to a file

lines = ['First line \n', 'Second line \n', 'Third line \n']
with open('example.txt', 'a') as file:
    file.writelines(lines)

# %%
## Binary Files

# Writing to a binary file
data = b'\x00\x01\x02\x03\x04'
with open('example.bin','wb') as file:
    file.write(data)

# %%
## Reading a Binary file

with open('example.bin','rb') as file:
    content=file.read()
    print(content)
# Out:
# b'\x00\x01\x02\x03\x04'

# %%
## Read the content from source text file and write to a destination text file
# copying a text file

with open('example.txt','r') as source_file:
    content = source_file.read()

with open('destination.txt','w') as destination_file:
    destination_file.write(content)

# %%
## Read a text file and count the number of lines, words and characters.
 # Counting lines, words, and characters in a text file

def count_text_file(file_path):
    with open('example.txt','r') as file:
        lines = file.readlines()
        line_count=len(lines)
        word_count=sum(len(line.split()) for line in lines)
        char_count=sum(len(line) for line in lines)
    return line_count,word_count,char_count

file_path = 'example.txt'
lines,words,characters = count_text_file(file_path)
print(f'Lines: {lines}, Words: {words}, Characters: {characters}')
# Out:
# Lines: 7, Words: 26, Characters: 200

# %% [markdown]
# The w+ mode in python is used to open a file for both Reading and Writing. If the file does not exist, it will be created. If the file exists, its content is truncated (ie.,the file is overwriten)

# %%
### Writing and then Reading a file

with open('example.txt', 'w+') as file:
    file.write("Hello World\n")
    file.write("This is a new line \n")

    ## Move the file cursor to the beginning
    file.seek(0)

    ##Read the content of the file
    content=file.read()
    print(content)
# Out:
# Hello World
# This is a new line
